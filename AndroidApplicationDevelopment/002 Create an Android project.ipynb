# %% [markdown]
# https://developer.android.com/training/basics/firstapp/creating-project
#
# # Create an Android project
#
# This lesson shows you how to create a new Android project with Android Studio, and it describes some of the files in the project.
#
# To create a new Android project, follow these steps:
#
# (1) Install the latest version of Android Studio.
#
# (2) In the Welcome to Android Studio window, click Start a new Android Studio project.![image.png](attachment:image.png)

# %% [markdown]
# If you have a project already opened, select File > New > New Project.
#
# (3) In the Choose your project window, select Empty Activity and click Next.
# ![image.png](attachment:image.png)
#
# (4) In the 'Configure Your Project' window, complete the following:
#
# - Enter "My First App" in the Name field.
# - Enter "com.example.myfirstapp" in the Package name field.
# - If you'd like to place the project in a different folder, change its Save location.
# - Select either Java or Kotlin from the Language drop-down menu.
# - Select the lowest version of Android your app will support in the Minimum SDK field.
# - If your app will require legacy library support, mark the "Use Legacy adnroid.support libraries" checkbox.
# - Leave the other options as they are.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# (5) Click Finish.
#
# After some processing time, the Android Studio main window appears.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Now take a moment to review the most important files.
#
# First, be sure the Project window is open (select View > Tool Windows > Project) and the Android view is selected from the drop-down list at the top of that window. You can then see the following files:

# %% [markdown]
# app > java > com.example.myfirstapp > MainActivity
# ![image.png](attachment:image.png)
#
#     This is the main activity. It's the entry point for your app. When you build and run your app, the system launches an instance opf this Activity and loads its layout.

# %% [markdown]
# app > res > layout > activity_main.xml
# ![image.png](attachment:image.png)
#
#     This XML files defines the layout for the activity's user interface (UI). It contains a TextView element with the text "Hello, World!"

# %% [markdown]
# app > manifests > AndroidManifest.xml
# ![image.png](attachment:image.png)
#
#     The manifest file describes the fundamental characteristics of the app and defines each of its components.

# %% [markdown]
# Gradle Scripts > build.gradle
# ![image.png](attachment:image.png)
#
#     There are two files with this name: one for the project, "Project: My First App," and one for the app module, "Module: app." Each module has its own build.grandle file, but this project currently has just one module. Use each module's "build.file" to control how the Gradle plugin builds your app. For more information about this file, see "Configure your build".
#
# To run the app, continue to the next lesson, "Run your app".
