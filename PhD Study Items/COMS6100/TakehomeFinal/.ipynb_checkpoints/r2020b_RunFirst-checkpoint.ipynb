# %%
import numpy as np
import matplotlib.pyplot as plt
import time             # added time. Used in testing and gave me an idea of runtime

# a basic rk4 routine implemented in octave
#  based on an rk4 routine from:
# https://math.okstate.edu/people/yqwang/teaching/math4513_fall11/Notes/rungekutta.pdf

# the code has been modified to use arbitrary function names, return
# output in an array, and have vectors of an arbitrary length for
# its input



def projectile(time, p): 
    x = p[0]
    z = p[1]
    vx = p[2]
    vz = p[3]

    # This is a 2trick to set the projectile constants as initial conditions 
    coeff = p[4] 

    drv = np.zeros(5, np.float)

    # the velocities are the derviative of position
    drv[0] = vx
    drv[1] = vz


    # calcualte the acceleration
    g = -9.8  # m/s - gravity
  
    ax = -coeff * vx * vx * np.sign(vx) 
    az = g  - np.sign(vz) * coeff * vz*vz


    # update the change vector
    drv[2] = ax
    drv[3] = az

    # we don't actually update the projectile constants since they are constant
    drv[4] = 0

    return drv

def myrungekutta(h, t, nsteps, y0):
    # rk4 routine  
    # inputs:
    #   h      - stepsize (dt)
    #   t      - starting time for the integration
    #   nsteps - number of steps to take during the integration
    #   y0     - initial conditions for the equation
    #
    #  outputs:
    #  output:  an array of the output values of system
    y = y0
    # find the number of values in the initial conditions array
    ny = len(y)
    output = np.zeros([1,ny+1], np.float)
    YCheck = 'False'
    
    # loop over the array and calculate the position using an rk4
    # ODE integration routine
    for i in range(nsteps):
        while YCheck == 'False':
            k1 = h*projectile(t,y)
            k2 = h*projectile(t+h/2, y+k1/2)
            k3 = h*projectile(t+h/2, y+k2/2)
            k4 = h*projectile(t+h, y+k3)
            y = y + (k1 + 2*(k2+k3) + k4)/6
            t = t + h

            output[i,0] = t
            output[i,1:] = y[:]
        
            if output[:,2][i] <= 0:     # added this to get only successful launches
                YCheck = 'True'
        
    return output

##################

##################
# integration parameters  

# initial position and air resistance
x =0
z =0
coeff = 0.005

# %%
# inputs are 
#  v- initial velocity of the projectile
#  theta - the angle above the ground
#  h = step size - generally below one
#  tfinal - final time in the simulation

h = float(0.0001)
tfinal = float(20.00)

# number of steps; irrelevant. choose something small
nsteps = int(tfinal / h) + 1

t = 0.0001

aResults = []
xResults = []
tResults = []

start_time = time.time()
for a in range(1, 90):
    for xv in np.arange(1, 381, 0.25):
        theta = a
        v = xv
        
        #v, theta, h, tfinal = input()
        
        vx = np.cos(theta * np.pi / 180.) * v
        vz = np.sin(theta * np.pi / 180.) * v
        
        # initial conditions for a circular projectile of unit size
        
        p0 = [x, z, vx, vz, coeff]
        
        o = myrungekutta(h, t, nsteps, p0)
        
        if o[:,1] >= 99 and o[:,1] <= 100:
            print("Success! Velocity = " + str(v) + " Angle = " + str(theta) + " Timestep = 0.0001 Time = " + str(o[:,0]) +" Current Runtime = " + str(round((time.time() - start_time), 2)))
            xResults.append(v)
            aResults.append(theta)
            tResults.append(float(o[:,0]))
            break
print("\n Total Runtime: " + str(time.time() - start_time))
# Out:
# Success! Velocity = 190.0 Angle = 1 Timestep = 0.00001 Time = [0.6759] Current Runtime = 89.68
# Success! Velocity = 134.5 Angle = 2 Timestep = 0.00001 Time = [0.9554] Current Runtime = 175.68
# Success! Velocity = 110.0 Angle = 3 Timestep = 0.00001 Time = [1.1701] Current Runtime = 263.25
# Success! Velocity = 95.25 Angle = 4 Timestep = 0.00001 Time = [1.3486] Current Runtime = 352.6
# Success! Velocity = 85.5 Angle = 5 Timestep = 0.00001 Time = [1.5103] Current Runtime = 441.64
# Success! Velocity = 78.25 Angle = 6 Timestep = 0.00001 Time = [1.6554] Current Runtime = 521.6
# Success! Velocity = 72.5 Angle = 7 Timestep = 0.00001 Time = [1.7857] Current Runtime = 603.06
# Success! Velocity = 68.0 Angle = 8 Timestep = 0.00001 Time = [1.91] Current Runtime = 687.83
# Success! Velocity = 64.25 Angle = 9 Timestep = 0.00001 Time = [2.0257] Current Runtime = 767.48
# Success! Velocity = 61.25 Angle = 10 Timestep = 0.00001 Time = [2.1404] Current Runtime = 844.61
# Success! Velocity = 58.5 Angle = 11 Timestep = 0.00001 Time = [2.2432] Current Runtime = 924.6
# Success! Velocity = 56.25 Angle = 12 Timestep = 0.00001 Time = [2.3468] Current Runtime = 1005.31
# Success! Velocity = 54.25 Angle = 13 Timestep = 0.00001 Time = [2.4452] Current Runtime = 1089.29
# Success! Velocity = 52.25 Angle = 14 Timestep = 0.00001 Time = [2.5295] Current Runtime = 1169.56
# Success! Velocity = 50.75 Angle = 15 Timestep = 0.00001 Time = [2.6245] Current Runtime = 1252.49
# Success! Velocity = 49.25 Angle = 16 Timestep = 0.00001 Time = [2.7086] Current Runtime = 1333.76
# Success! Velocity = 48.0 Angle = 17 Timestep = 0.00001 Time = [2.796] Current Runtime = 1421.76
# Success! Velocity = 47.0 Angle = 18 Timestep = 0.00001 Time = [2.8888] Current Runtime = 1512.15
# Success! Velocity = 46.0 Angle = 19 Timestep = 0.00001 Time = [2.9742] Current Runtime = 1602.08
# Success! Velocity = 45.0 Angle = 20 Timestep = 0.00001 Time = [3.0521] Current Runtime = 1684.55
# Success! Velocity = 44.0 Angle = 21 Timestep = 0.00001 Time = [3.1227] Current Runtime = 1769.22
# Success! Velocity = 43.25 Angle = 22 Timestep = 0.00001 Time = [3.2034] Current Runtime = 1855.1
# Success! Velocity = 42.5 Angle = 23 Timestep = 0.00001 Time = [3.2784] Current Runtime = 1940.52
# Success! Velocity = 42.0 Angle = 24 Timestep = 0.00001 Time = [3.3664] Current Runtime = 2027.49
# Success! Velocity = 41.25 Angle = 25 Timestep = 0.00001 Time = [3.4306] Current Runtime = 2114.91
# Success! Velocity = 40.75 Angle = 26 Timestep = 0.00001 Time = [3.5094] Current Runtime = 2200.17
# Success! Velocity = 40.25 Angle = 27 Timestep = 0.00001 Time = [3.5839] Current Runtime = 2289.89
# Success! Velocity = 39.75 Angle = 28 Timestep = 0.00001 Time = [3.6542] Current Runtime = 2378.1
# Success! Velocity = 39.5 Angle = 29 Timestep = 0.00001 Time = [3.7422] Current Runtime = 2472.94
# Success! Velocity = 39.0 Angle = 30 Timestep = 0.00001 Time = [3.8049] Current Runtime = 2562.09
# Success! Velocity = 38.75 Angle = 31 Timestep = 0.00001 Time = [3.8866] Current Runtime = 2653.53
# Success! Velocity = 38.5 Angle = 32 Timestep = 0.00001 Time = [3.9653] Current Runtime = 2747.19
# Success! Velocity = 38.25 Angle = 33 Timestep = 0.00001 Time = [4.0413] Current Runtime = 2852.39
# Success! Velocity = 38.0 Angle = 34 Timestep = 0.00001 Time = [4.1144] Current Runtime = 2946.55
# Success! Velocity = 37.75 Angle = 35 Timestep = 0.00001 Time = [4.1847] Current Runtime = 3048.16
# Success! Velocity = 37.5 Angle = 36 Timestep = 0.00001 Time = [4.2523] Current Runtime = 3144.37
# Success! Velocity = 37.25 Angle = 37 Timestep = 0.00001 Time = [4.3172] Current Runtime = 3244.23
# Success! Velocity = 37.25 Angle = 38 Timestep = 0.00001 Time = [4.4057] Current Runtime = 3344.94
# Success! Velocity = 37.0 Angle = 39 Timestep = 0.00001 Time = [4.4657] Current Runtime = 3447.32
# Success! Velocity = 37.0 Angle = 40 Timestep = 0.00001 Time = [4.5503] Current Runtime = 3552.76
# Success! Velocity = 37.0 Angle = 41 Timestep = 0.00001 Time = [4.633] Current Runtime = 3659.75
# Success! Velocity = 37.0 Angle = 42 Timestep = 0.00001 Time = [4.7139] Current Runtime = 3765.37
# Success! Velocity = 37.0 Angle = 43 Timestep = 0.00001 Time = [4.7931] Current Runtime = 3876.12
# Success! Velocity = 37.0 Angle = 44 Timestep = 0.00001 Time = [4.8704] Current Runtime = 3997.97
# Success! Velocity = 37.0 Angle = 45 Timestep = 0.00001 Time = [4.946] Current Runtime = 4112.95
# Success! Velocity = 37.0 Angle = 46 Timestep = 0.00001 Time = [5.0197] Current Runtime = 4234.68
# Success! Velocity = 37.0 Angle = 47 Timestep = 0.00001 Time = [5.0917] Current Runtime = 4349.75
# Success! Velocity = 37.25 Angle = 48 Timestep = 0.00001 Time = [5.1916] Current Runtime = 4481.25
# Success! Velocity = 37.25 Angle = 49 Timestep = 0.00001 Time = [5.2602] Current Runtime = 4608.01
# Success! Velocity = 37.5 Angle = 50 Timestep = 0.00001 Time = [5.3573] Current Runtime = 4731.64
# Success! Velocity = 37.75 Angle = 51 Timestep = 0.00001 Time = [5.453] Current Runtime = 4867.13
# Success! Velocity = 37.75 Angle = 52 Timestep = 0.00001 Time = [5.5167] Current Runtime = 4994.53
# Success! Velocity = 38.0 Angle = 53 Timestep = 0.00001 Time = [5.6094] Current Runtime = 5123.88
# Success! Velocity = 38.25 Angle = 54 Timestep = 0.00001 Time = [5.7007] Current Runtime = 5262.41
# Success! Velocity = 38.75 Angle = 55 Timestep = 0.00001 Time = [5.8213] Current Runtime = 5399.28
# Success! Velocity = 39.0 Angle = 56 Timestep = 0.00001 Time = [5.9096] Current Runtime = 5539.8
# Success! Velocity = 39.25 Angle = 57 Timestep = 0.00001 Time = [5.9964] Current Runtime = 5694.76
# Success! Velocity = 39.75 Angle = 58 Timestep = 0.00001 Time = [6.1126] Current Runtime = 5850.54
# Success! Velocity = 40.25 Angle = 59 Timestep = 0.00001 Time = [6.2272] Current Runtime = 6012.26
# Success! Velocity = 40.75 Angle = 60 Timestep = 0.00001 Time = [6.3401] Current Runtime = 6175.2
# Success! Velocity = 41.25 Angle = 61 Timestep = 0.00001 Time = [6.4514] Current Runtime = 6345.88
# Success! Velocity = 41.75 Angle = 62 Timestep = 0.00001 Time = [6.561] Current Runtime = 6519.08
# Success! Velocity = 42.5 Angle = 63 Timestep = 0.00001 Time = [6.6992] Current Runtime = 6707.03
# Success! Velocity = 43.0 Angle = 64 Timestep = 0.00001 Time = [6.805] Current Runtime = 6890.43
# Success! Velocity = 43.75 Angle = 65 Timestep = 0.00001 Time = [6.9391] Current Runtime = 7099.75
# Success! Velocity = 44.75 Angle = 66 Timestep = 0.00001 Time = [7.1007] Current Runtime = 7314.6
# Success! Velocity = 45.5 Angle = 67 Timestep = 0.00001 Time = [7.2299] Current Runtime = 7520.94
# Success! Velocity = 46.5 Angle = 68 Timestep = 0.00001 Time = [7.3859] Current Runtime = 7745.91
# Success! Velocity = 47.5 Angle = 69 Timestep = 0.00001 Time = [7.5389] Current Runtime = 7988.41
# Success! Velocity = 48.75 Angle = 70 Timestep = 0.00001 Time = [7.717] Current Runtime = 8235.79
# Success! Velocity = 50.0 Angle = 71 Timestep = 0.00001 Time = [7.8912] Current Runtime = 8495.58
# Success! Velocity = 51.5 Angle = 72 Timestep = 0.00001 Time = [8.0885] Current Runtime = 8772.36
# Success! Velocity = 53.0 Angle = 73 Timestep = 0.00001 Time = [8.2808] Current Runtime = 9060.56
# Success! Velocity = 54.75 Angle = 74 Timestep = 0.00001 Time = [8.494] Current Runtime = 9363.36
# Success! Velocity = 56.75 Angle = 75 Timestep = 0.00001 Time = [8.7262] Current Runtime = 9702.77
# Success! Velocity = 59.0 Angle = 76 Timestep = 0.00001 Time = [8.9754] Current Runtime = 10051.83
# Success! Velocity = 61.75 Angle = 77 Timestep = 0.00001 Time = [9.2628] Current Runtime = 10434.83
# Success! Velocity = 64.75 Angle = 78 Timestep = 0.00001 Time = [9.5609] Current Runtime = 10864.79
# Success! Velocity = 68.25 Angle = 79 Timestep = 0.00001 Time = [9.8889] Current Runtime = 11361.04
# Success! Velocity = 72.25 Angle = 80 Timestep = 0.00001 Time = [10.2413] Current Runtime = 11909.75
# Success! Velocity = 77.25 Angle = 81 Timestep = 0.00001 Time = [10.651] Current Runtime = 12521.18
# Success! Velocity = 83.25 Angle = 82 Timestep = 0.00001 Time = [11.1051] Current Runtime = 13207.03
# Success! Velocity = 90.75 Angle = 83 Timestep = 0.00001 Time = [11.6235] Current Runtime = 14005.85
# Success! Velocity = 100.5 Angle = 84 Timestep = 0.00001 Time = [12.2295] Current Runtime = 14965.68
# Success! Velocity = 113.75 Angle = 85 Timestep = 0.00001 Time = [12.9541] Current Runtime = 16158.05
# Success! Velocity = 132.75 Angle = 86 Timestep = 0.00001 Time = [13.8411] Current Runtime = 17603.06
# Success! Velocity = 163.25 Angle = 87 Timestep = 0.00001 Time = [14.9997] Current Runtime = 19549.84
# Success! Velocity = 220.75 Angle = 88 Timestep = 0.00001 Time = [16.6332] Current Runtime = 22596.13
# Success! Velocity = 378.25 Angle = 89 Timestep = 0.00001 Time = [19.4069] Current Runtime = 29689.97
#
#  Total Runtime: 29689.967606306076

# %%
with open("all_inputs.txt", "w") as file:
    for i in range(0, len(aResults)):
        file.write('\n' + str(aResults[i]) + ',' + str(xResults[i]) + ',' + str(tResults[i]) + ',' + str(t))

# %%
plt.title('Theta Vs Velocity')
plt.ylabel('Velocity')
plt.xlabel('Theta')
plt.plot(aResults, xResults)
#plt.savefig('ThetaV')
plt.show()

# %%
plt.title('Theta Vs Time')
plt.ylabel('Time')
plt.xlabel('Theta')
plt.plot(aResults, tResults)
#plt.savefig('ThetaT')
plt.show()
