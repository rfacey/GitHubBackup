# %% [markdown]
# # More Files
#
# Now let's do a few more things with files. We'll write a Python script to copy one file to another. It'll be very short but will give you ideas about other things you can do with files.
#
# ![image.png](attachment:image.png)
#
# You should immediately notice that we import another handy command named exists.  This returns True if a file exist, based on its name in a string as an argument. It returns False if not. We'll be using this function in the second half of this book to do lots of things, but right now you should see how you can import it.
#
# Using import is a way to get tons of free code other better (well, usually) programmers have written so you do noit have to write it.
#
# ## What You Should See
#
# Just like your other scripts, run this one with two arguments: the file to copy from and the file to copy it to. I'm going to use a simple test file named test.txt:

# %% [markdown]
# ![image.png](attachment:image.png)
#
# It should work with any file. Try a bunch more and see what happens. Just be careful you do not blast an important file.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Study Drills
#
# 1. This script is really annoying. There's no need to ask you before doing the copy, and it prints too much out to the screen. Try to make the script more friendly to use by removing features.
# 2. See how short you can make the script. I could make this one line long.
# 3. Notice at the end of the What You Should See section I used something called cat? It's an old command that concatenates files together, but mostly it's just an easy way to print a file to the screen. Type man cat to read about it.
# 4. Find out why you had to write out_file.close() in the code.
# 5. Go read up on Python's import statement, and start python3.6 to try it out. Try importing some things and see if you can get it right. It's alright if you do not.
#
# ## Common Student Questions
#
# - Q: Why is the 'w' in quotes? A: THat's a string. You've ebeen using strings for a while now. Make sure you know what a string is.
# - Q: No way you can make this one line! A: That ; depends ; on ; how ; you ; define ; one ; line ; of ; code.
# - Q: Is it normal to feel like this exercise was really hard? A: Yes, it is totally normal. Programming may not "click" for you until maybe even Exercise 36, of it might not until you finish the book and then make something with Python. Everyone is different, so just keep going and keep reviewing exercises that you had trouble with until it clicks. Be patient.
# - Q: What does the len() function do? A: It gets the length of the string that you pass to it then returns that as a number. Play with it.
# - Q: When I try to make this script shorter I get an error when I close the files at the end. A: You probably did something like indata = open(from_file).read(), which means you don't need to then do in_file.close() when you reach the end of the script. It should already be closed by Python once that one line runs.
# - Q: I get a Syntax:EOL while scanning string literal error. A: You forgot to end a string properly with a quote. Go look at that line again.
